# %% [markdown]
# # Implementation and evaluation of models for Cross-subject classification

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import sys, os
import h5py
import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf
from tensorflow.keras import datasets, layers, models

np.random.seed(0)

# %% [markdown]
# ### Data utils

# %%
def get_dataset_name(file_name_with_dir):
    filename_without_dir = file_name_with_dir.split('/')[-1]
    temp = filename_without_dir.split('_')[:-1]
    dataset_name = "_".join(temp)
    return dataset_name


def normalize(matrix, class_id, maxs_array, mins_array):
  maxs = maxs_array[:, class_id]
  maxs = maxs.reshape(maxs.shape[0],1)
  mins = mins_array[:, class_id]
  mins = mins.reshape(mins.shape[0],1)
  return (matrix-mins)/(maxs-mins)

def subsample(matrix, downsampling_factor=10):
  return matrix[:, ::downsampling_factor]

# %% [markdown]
# ### Data generators

# %%
def train_val_generator(train_data_dir, mode='training', downsampling_factor=10, val_split=0.2, shuffle=False, window_size=1000, window_shift=50, maxs_array=None, mins_array=None):
  '''
  Generate 4 chunk, one one class
  '''
  
  class_names=['rest', 'task_motor', 'task_story_math', 'task_working_memory']
  
  subject_id_list = [113922, 164636]
  sub_idx = 0
  chunk_id = 1

  while True:
      
    np.random.seed(chunk_id)
    
    # Initialize the dataset
    data_X = []
    data_Y = []

    subject_id = subject_id_list[sub_idx]

    for class_id, class_name in enumerate(class_names):
      filename_path = train_data_dir + '/' + class_name + '_' + str(subject_id) + '_' + str(chunk_id) + '.h5'

      ### Supplied code
      with h5py.File(filename_path,'r') as f:
        dataset_name = get_dataset_name(filename_path)
        matrix = f.get(dataset_name)[()]
      ###

      matrix = normalize(matrix, class_id, maxs_array, mins_array)
      matrix = subsample(matrix, downsampling_factor)
      matrix = matrix.T
      for i in range(window_size-1, matrix.shape[0], window_shift):
        x_instance = matrix[i-window_size+1: i+1, :]
        data_X.append(x_instance)
        data_Y.append(class_id)


    data_X = np.asarray(data_X)
    data_X = data_X.astype(np.float16)
    data_Y = np.asarray(data_Y).astype(np.int8)


    # Shuffle
    if shuffle:
      indices = np.arange(data_X.shape[0])
      np.random.shuffle(indices)
      data_X = data_X[indices,:,:]
      data_Y = data_Y[indices]
        
    n_instances = data_X.shape[0]
    n_instances_train = round((1-val_split)*n_instances)
    
    if mode == 'training':
      # Take first 'n_instances_train' instances of the dataset
      #print("\nYielding: Sub {}  |  Chunk set {} (training)".format(subject_id_list[sub_idx], chunk_id))
      yield data_X[:n_instances_train,:,:], data_Y[:n_instances_train]


    if mode == 'validation':
      # Take the remaining instances as validation set
      yield data_X[n_instances_train:,:,:], data_Y[n_instances_train:]


    chunk_id += 1
    if chunk_id > 8:
      chunk_id = 1

      sub_idx += 1
      if sub_idx > 1:
        sub_idx = 0

      #raise Exception("All files yielded")
  

def test_generator(test_data_dir, downsampling_factor=10, window_size=1000, window_shift=50, maxs_array=None, mins_array=None):
  '''
  Generate data from a single h5 file 
  '''
  
  class_names_list=['rest','task_motor','task_story_math','task_working_memory']

  file_names = sorted(os.listdir(test_data_dir))

  while True:

    for file_name in file_names:
      # Initialize the dataset
      test_data_X = []
      test_data_Y = []
      
      filename_path = test_data_dir + file_name
      class_name = '_'.join((file_name.split('_')[:-2]))
      class_id = class_names_list.index(class_name)

      ### Supplied code
      with h5py.File(filename_path,'r') as f:
        dataset_name = get_dataset_name(filename_path)
        matrix = f.get(dataset_name)[()]
      ###

      matrix = normalize(matrix, class_id, maxs_array, mins_array)
      matrix = subsample(matrix, downsampling_factor)
      matrix = matrix.T
      for i in range(window_size-1, matrix.shape[0], window_shift):
        x_instance = matrix[i-window_size+1: i+1, :]
        test_data_X.append(x_instance)
        test_data_Y.append(class_id)

      test_data_X = np.asarray(test_data_X).astype(np.float16)
      test_data_Y = np.asarray(test_data_Y).astype(np.int8)

      # print("Yielding chunk set: ",chunk_id)
      yield test_data_X, test_data_Y

# %% [markdown]
# ### Configuration

# %%
# CROSS train 

train_data_dir = "/content/drive/My Drive/DL-final_project/Data/Cross/train/"
cross_base_dir = "/content/drive/My Drive/DL-final_project/Data/Cross"

train_subject_id_list = [113922, 164636]

class_names = ['rest', 'task_motor', 'task_story_math', 'task_working_memory']
n_sensors = 248        # FIXED: No. of features (sensors) in the signal
steps_per_file = 35624 # FIXED


# Data preprocessing params
DOWNSAMPLING_FACTOR = 10
WINDOW_SIZE = 100
WINDOW_SHIFT = 10
VAL_SPLIT = 0.2
SHUFFLE = True

# Baseline hyper-params
HYPER_PARAMS = {'lr': 0.001, 'batch_norm':False, 'dropout_prob':0.0}
N_CONV_LAYERS = 3
KERNELS = [32,32,64]
KERNEL_SIZES = [3,3,3]

# Training
EPOCHS = 50

# Normalization stuff
maxs_file_path = "/content/drive/My Drive/DL-final_project/data_stats/cross_train_maxs.txt"
mins_file_path = "/content/drive/My Drive/DL-final_project/data_stats/cross_train_mins.txt"
maxs_array = np.loadtxt(maxs_file_path, delimiter=',')
mins_array = np.loadtxt(mins_file_path, delimiter=',')

# %% [markdown]
# ### Model definition

# %%
def CNN_model_cross(window_size, n_conv_layers, kernels, kernel_sizes, hyper_params={'lr':0.001, 'batch_norm':False, 'dropout_prob':0.0}, initializer='glorot_uniform'):
    tf.random.set_seed(0)
    tf.keras.backend.clear_session()

    model = models.Sequential()
    model.add(layers.Conv1D(filters=kernels[0], kernel_size=kernel_sizes[0], strides=1, 
                            activation='relu', 
                            kernel_initializer=initializer,
                            input_shape=(window_size, 248)))

    if hyper_params['batch_norm']:
      model.add(layers.BatchNormalization())

    for i in range(1, n_conv_layers):
        model.add(layers.Conv1D(filters=kernels[i], kernel_size=kernel_sizes[i], strides=1, activation='relu', kernel_initializer=initializer))
        if hyper_params['batch_norm']:
          model.add(layers.BatchNormalization())
        model.add(layers.MaxPooling1D(pool_size=2))
    
    model.add(layers.Flatten())

    model.add(layers.Dense(units=64, activation='relu', kernel_initializer=initializer))
    if hyper_params['dropout_prob'] != 0.0:
      model.add(layers.Dropout(hyper_params['dropout_prob']))

    model.add(layers.Dense(units=64, activation='relu', kernel_initializer=initializer))
    if hyper_params['dropout_prob'] != 0.0:
      model.add(layers.Dropout(hyper_params['dropout_prob']))

    model.add(layers.Dense(units=4, activation='softmax'))

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hyper_params['lr']),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()
    return model

#model = CNN_model_cross(window_size=100, n_conv_layers=6, kernels=[32,32,64,64,128,256], kernel_sizes=[3,3,3,3,3,3])

# %% [markdown]
# ### Baseline model

# %%
# Baseline hyper-params
baseline = CNN_model_cross(WINDOW_SIZE,
                    N_CONV_LAYERS, KERNELS, KERNEL_SIZES, 
                    HYPER_PARAMS)

tf.keras.utils.plot_model(baseline, 
                          to_file='/content/drive/My Drive/DL-final_project/Results/Cross/baseline_arch.png', 
                          show_shapes=True, show_layer_names=False,
                          rankdir='TB', expand_nested=False, dpi=96)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 98, 32)            23840
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 96, 32)            3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 48, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 46, 64)            6208
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 23, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1472)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                94272
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 131,844
# Trainable params: 131,844
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Experiment 1: Number of Layers

# %%
# Sweep config

n_conv_layers_list = [3, 4, 5, 6]
kernels_list = [[32,32,64],
                [32,32,64,64],
                [32,32,64,64,128],
                [32,32,64,64,128,256]]
kernel_sizes_list = [[3,3,3],
                     [3,3,3,3],
                     [3,3,3,3,3],
                     [3,3,3,3,3,3]]

n_conv_layers_list = [6]
kernels_list = [[32,32,64,64,128,256]]
kernel_sizes_list = [[3,3,3,3,3,3]]

# Callback config
base_log_dir = "/content/drive/My Drive/DL-final_project/Results/Cross/Expt1-nLayers/logs/"

# %%
for i, n_conv_layers in enumerate(n_conv_layers_list):
  # Set up callback
  log_dir = base_log_dir + str(n_conv_layers) + "_layer/"
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir, histogram_freq=0, write_graph=True, write_images=False,
      update_freq='epoch', profile_batch=2, embeddings_freq=0,
      embeddings_metadata=None)

  # Initialize data generators
  train_generator = train_val_generator(train_data_dir,
                                                 'training', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                                 WINDOW_SIZE, WINDOW_SHIFT, 
                                                 maxs_array, mins_array)

  val_generator = train_val_generator(train_data_dir, 
                                               'validation', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                               WINDOW_SIZE, WINDOW_SHIFT, 
                                               maxs_array, mins_array)

  # Initialize model
  kernels = kernels_list[i]
  kernel_sizes = kernel_sizes_list[i]
  model = CNN_model_cross(WINDOW_SIZE,
                    n_conv_layers, kernels, kernel_sizes, 
                    HYPER_PARAMS)
  
  # Start training
  print("EXPT CASE: N Conv Layers-", n_conv_layers)
  model.fit(train_generator,
              steps_per_epoch = 16,
              validation_data = val_generator,
              validation_steps = 16,
              epochs = EPOCHS,
              callbacks=[tensorboard_callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 98, 32)            23840
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 96, 32)            3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 48, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 46, 64)            6208
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 23, 64)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 21, 64)            12352
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 10, 64)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 8, 128)            24704
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 4, 128)            0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 2, 256)            98560
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 1, 256)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 189,636
# Trainable params: 189,636
# Non-trainable params: 0
# _________________________________________________________________
# EXPT CASE: N Conv Layers- 6
# Epoch 1/50
# 16/16 [==============================] - 350s 22s/step - loss: 1.1490 - accuracy: 0.5037 - val_loss: 0.9006 - val_accuracy: 0.6356
# Epoch 2/50
# 16/16 [==============================] - 43s 3s/step - loss: 1.0472 - accuracy: 0.5209 - val_loss: 0.8963 - val_accuracy: 0.7147
# Epoch 3/50
# 16/16 [==============================] - 43s 3s/step - loss: 0.8917 - accuracy: 0.5485 - val_loss: 0.8654 - val_accuracy: 0.6288
# Epoch 4/50
# 16/16 [==============================] - 43s 3s/step - loss: 0.8521 - accuracy: 0.6305 - val_loss: 0.8105 - val_accuracy: 0.6936
# Epoch 5/50
# 16/16 [==============================] - 43s 3s/step - loss: 0.8269 - accuracy: 0.6592 - val_loss: 0.7493 - val_accuracy: 0.6592
# Epoch 6/50
# 16/16 [==============================] - 43s 3s/step - loss: 0.6997 - accuracy: 0.7069 - val_loss: 0.8125 - val_accuracy: 0.7053
# Epoch 7/50
# 16/16 [==============================] - 43s 3s/step - loss: 0.7396 - accuracy: 0.6827 - val_loss: 0.9652 - val_accuracy: 0.6619
# Epoch 8/50
# 16/16 [==============================] - 43s 3s/step - loss: 0.6294 - accuracy: 0.7159 - val_loss: 0.8017 - val_accuracy: 0.7657
# Epoch 9/50
# 16/16 [==============================] - 43s 3s/step - loss: 0.6963 - accuracy: 0.6614 - val_loss: 0.8435 - val_accuracy: 0.7221
# Epoch 10/50
# 16/16 [==============================] - 43s 3s/step - loss: 0.4850 - accuracy: 0.8789 - val_loss: 0.6797 - val_accuracy: 0.7732
# Epoch 11/50
# 16/16 [==============================] - 43s 3s/step - loss: 0.3637 - accuracy: 0.8709 - val_loss: 2.0398 - val_accuracy: 0.6003
# Epoch 12/50
# 16/16 [==============================] - 43s 3s/step - loss: 0.5536 - accuracy: 0.8209 - val_loss: 0.8185 - val_accuracy: 0.7750
# Epoch 13/50
# 16/16 [==============================] - 43s 3s/step - loss: 0.7280 - accuracy: 0.7624 - val_loss: 0.4965 - val_accuracy: 0.8817
# Epoch 14/50
# 16/16 [==============================] - 43s 3s/step - loss: 0.4062 - accuracy: 0.9142 - val_loss: 0.2172 - val_accuracy: 0.9593
# Epoch 15/50
# 16/16 [==============================] - 43s 3s/step - loss: 0
50
# 16/16 [==============================] - 45s 3s/step - loss: 0.0473 - accuracy: 0.9841 - val_loss: 0.0440 - val_accuracy: 0.9829
# Epoch 45/50
# 16/16 [==============================] - 45s 3s/step - loss: 0.0514 - accuracy: 0.9828 - val_loss: 0.0475 - val_accuracy: 0.9811
# Epoch 46/50
# 16/16 [==============================] - 46s 3s/step - loss: 0.0442 - accuracy: 0.9838 - val_loss: 0.0393 - val_accuracy: 0.9838
# Epoch 47/50
# 16/16 [==============================] - 46s 3s/step - loss: 0.0408 - accuracy: 0.9841 - val_loss: 0.0387 - val_accuracy: 0.9834
# Epoch 48/50
# 16/16 [==============================] - 45s 3s/step - loss: 0.0471 - accuracy: 0.9830 - val_loss: 0.0447 - val_accuracy: 0.9811
# Epoch 49/50
# 16/16 [==============================] - 46s 3s/step - loss: 0.0396 - accuracy: 0.9838 - val_loss: 0.0360 - val_accuracy: 0.9838
# Epoch 50/50
# 16/16 [==============================] - 47s 3s/step - loss: 0.0370 - accuracy: 0.9842 - val_loss: 0.0333 - val_accuracy: 0.9847

# %% [markdown]
# ## Experiment 2: Kernel sizes

# %%
# Baseline config
EPOCHS=30
N_CONV_LAYERS=3
KERNELS=[32,32,64]

# Sweep config
kernel_sizes_list = [[5,3,3],
                    [5,5,3],
                    [7,3,3],
                    [7,5,3]]

# Callback config
base_log_dir = "/content/drive/My Drive/DL-final_project/Results/Cross/Expt2-kernelSize/logs/"

# %%
for i, kernel_sizes in enumerate(kernel_sizes_list):
  # Set up callback
  log_dir = base_log_dir +  "{}-{}-{}_kernelSize/".format(kernel_sizes[0], kernel_sizes[1], kernel_sizes[2])
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir, histogram_freq=0, write_graph=True, write_images=False,
      update_freq='epoch', profile_batch=2, embeddings_freq=0,
      embeddings_metadata=None)

  # Initialize data generators
  train_generator = train_val_generator(train_data_dir, 
                                                 'training', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                                 WINDOW_SIZE, WINDOW_SHIFT, 
                                                 maxs_array, mins_array)

  val_generator = train_val_generator(train_data_dir, 
                                               'validation', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                               WINDOW_SIZE, WINDOW_SHIFT, 
                                               maxs_array, mins_array)

  # Initialize model
  model = CNN_model_cross(WINDOW_SIZE,
                    N_CONV_LAYERS, KERNELS, kernel_sizes, 
                    HYPER_PARAMS)
  
  # Start training
  print("EXPT CASE:  Kernel sizes-", kernel_sizes)
  model.fit(train_generator,
              steps_per_epoch = 16,
              validation_data = val_generator,
              validation_steps = 16,
              epochs = EPOCHS,
              callbacks=[tensorboard_callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 96, 32)            39712
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 94, 32)            3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 47, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 45, 64)            6208
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 22, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1408)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                90176
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 143,620
# Trainable params: 143,620
# Non-trainable params: 0
# _________________________________________________________________
# EXPT CASE:  Kernel sizes- [5, 3, 3]
# Epoch 1/30
# 16/16 [==============================] - 50s 3s/step - loss: 1.3074 - accuracy: 0.3811 - val_loss: 1.1751 - val_accuracy: 0.4224
# Epoch 2/30
# 16/16 [==============================] - 47s 3s/step - loss: 0.9634 - accuracy: 0.5708 - val_loss: 0.7253 - val_accuracy: 0.6693
# Epoch 3/30
# 16/16 [==============================] - 47s 3s/step - loss: 0.7323 - accuracy: 0.6482 - val_loss: 1.0063 - val_accuracy: 0.6232
# Epoch 4/30
# 16/16 [==============================] - 48s 3s/step - loss: 0.7832 - accuracy: 0.6741 - val_loss: 0.6530 - val_accuracy: 0.7527
# Epoch 5/30
# 16/16 [==============================] - 47s 3s/step - loss: 0.5909 - accuracy: 0.8187 - val_loss: 0.5731 - val_accuracy: 0.7678
# Epoch 6/30
# 16/16 [==============================] - 47s 3s/step - loss: 0.4923 - accuracy: 0.7758 - val_loss: 0.4353 - val_accuracy: 0.8545
# Epoch 7/30
# 16/16 [==============================] - 47s 3s/step - loss: 0.4218 - accuracy: 0.8314 - val_loss: 0.2337 - val_accuracy: 0.8939
# Epoch 8/30
# 16/16 [==============================] - 49s 3s/step - loss: 0.2806 - accuracy: 0.8851 - val_loss: 0.1460 - val_accuracy: 0.9710
# Epoch 9/30
# 16/16 [==============================] - 47s 3s/step - loss: 0.1576 - accuracy: 0.9664 - val_loss: 0.1513 - val_accuracy: 0.9645
# Epoch 10/30
# 16/16 [==============================] - 48s 3s/step - loss: 0.2535 - accuracy: 0.9273 - val_loss: 0.1611 - val_accuracy: 0.9400
# Epoch 11/30
# 16/16 [==============================] - 47s 3s/step - loss: 0.7223 - accuracy: 0.7912 - val_loss: 0.7450 - val_accuracy: 0.7376
# Epoch 12/30
# 16/16 [==============================] - 47s 3s/step - loss: 0.3830 - accuracy: 0.8632 - val_loss: 0.2838 - val_accuracy: 0.9031
# Epoch 13/30
# 16/16 [==============================] - 48s 3s/step - loss: 0.2655 - accuracy: 0.8963 - val_loss: 0.1618 - val_accuracy: 0.9427
# Epoch 14/30
# 16/16 [==============================] - 47s 3s/step - loss: 0.1852 - accuracy: 0.9367 - val_loss: 0.1039 - val_accuracy: 0.9777
# Epoch 15/30
# 16/16 [==============================] - 46s 3s/step - loss: 0.1205 - accuracy: 0.9756 - val_loss: 0.2763 - val_accuracy: 0.8656
# Epoch 16/30
# 16/16 [==============================] - 47s 3s/step - loss: 0
# 16/16 [==============================] - 169s 11s/step - loss: 0.2221 - accuracy: 0.9242 - val_loss: 0.7285 - val_accuracy: 0.8375
# Epoch 14/30
# 16/16 [==============================] - 169s 11s/step - loss: 0.3409 - accuracy: 0.8679 - val_loss: 0.4530 - val_accuracy: 0.8685
# Epoch 15/30
# 16/16 [==============================] - 101s 6s/step - loss: 0.5180 - accuracy: 0.7799 - val_loss: 0.3904 - val_accuracy: 0.7446
# Epoch 16/30
# 16/16 [==============================] - 51s 3s/step - loss: 0.3724 - accuracy: 0.8462 - val_loss: 0.1610 - val_accuracy: 0.9643
# Epoch 17/30
# 16/16 [==============================] - 50s 3s/step - loss: 0.2465 - accuracy: 0.9382 - val_loss: 0.3887 - val_accuracy: 0.8871
# Epoch 18/30
# 16/16 [==============================] - 49s 3s/step - loss: 0.3160 - accuracy: 0.8829 - val_loss: 0.8237 - val_accuracy: 0.8862
# Epoch 19/30
# 16/16 [==============================] - 49s 3s/step - loss: 0.7032 - accuracy: 0.8130 - val_loss: 0.4240 - val_accuracy: 0.8485
# Epoch 20/30
# 16/16 [==============================] - 49s 3s/step - loss: 0.2957 - accuracy: 0.9057 - val_loss: 0.8797 - val_accuracy: 0.8289
# Epoch 21/30
# 16/16 [==============================] - 49s 3s/step - loss: 0.5464 - accuracy: 0.8144 - val_loss: 0.8937 - val_accuracy: 0.7239
# Epoch 22/30
# 16/16 [==============================] - 49s 3s/step - loss: 0.5486 - accuracy: 0.8690 - val_loss: 0.4952 - val_accuracy: 0.8330
# Epoch 23/30
# 16/16 [==============================] - 49s 3s/step - loss: 0.4125 - accuracy: 0.8479 - val_loss: 0.6523 - val_accuracy: 0.8613
# Epoch 24/30
# 16/16 [==============================] - 49s 3s/step - loss: 0.4864 - accuracy: 0.8307 - val_loss: 0.6540 - val_accuracy: 0.8905
# Epoch 25/30
# 16/16 [==============================] - 49s 3s/step - loss: 0.4218 - accuracy: 0.8454 - val_loss: 0.5040 - val_accuracy: 0.9020
# Epoch 26/30
# 16/16 [==============================] - 50s 3s/step - loss: 0.3614 - accuracy: 0.8588 - val_loss: 0.2660 - val_accuracy: 0.8876
# Epoch 27/30
# 16/16 [==============================] - 50s 3s/step - loss: 0.1653 - accuracy: 0.9604 - val_loss: 0.3715 - val_accuracy: 0.8851
# Epoch 28/30
# 16/16 [==============================] - 50s 3s/step - loss: 0.2145 - accuracy: 0.9190 - val_loss: 0.3512 - val_accuracy: 0.9454
# Epoch 29/30
# 16/16 [==============================] - 51s 3s/step - loss: 0.3712 - accuracy: 0.8484 - val_loss: 0.6548 - val_accuracy: 0.7156
# Epoch 30/30
# 16/16 [==============================] - 50s 3s/step - loss: 0.6452 - accuracy: 0.7293 - val_loss: 0.4104 - val_accuracy: 0.7646

# %% [markdown]
# ## Experiment 3: Batch normalization

# %%
# Callback config
base_log_dir = "/content/drive/My Drive/DL-final_project/Results/Cross/Expt3-batchNorm/logs/"
EPOCHS=30

for batch_norm in [False, True]:

  # Set up callback
  log_dir = base_log_dir +  "{}_batchNorm/".format(int(batch_norm))
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir, histogram_freq=0, write_graph=True, write_images=False,
      update_freq='epoch', profile_batch=2, embeddings_freq=0,
      embeddings_metadata=None)

  # Initialize data generators
  train_generator = train_val_generator(train_data_dir, 
                                                 'training', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                                 WINDOW_SIZE, WINDOW_SHIFT, 
                                                 maxs_array, mins_array)

  val_generator = train_val_generator(train_data_dir, 
                                               'validation', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                               WINDOW_SIZE, WINDOW_SHIFT, 
                                               maxs_array, mins_array)

  # Initialize model
  model = CNN_model_cross(WINDOW_SIZE,
                    N_CONV_LAYERS, KERNELS, KERNEL_SIZES, 
                    hyper_params={'lr':0.001, 'batch_norm':batch_norm, 'dropout_prob':0.0})
  
  # Start training
  print("EXPT CASE:  Batch norm-", batch_norm)
  model.fit(train_generator,
              steps_per_epoch = 16,
              validation_data = val_generator,
              validation_steps = 16,
              epochs = EPOCHS,
              callbacks=[tensorboard_callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 98, 32)            23840
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 96, 32)            3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 48, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 46, 64)            6208
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 23, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1472)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                94272
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 131,844
# Trainable params: 131,844
# Non-trainable params: 0
# _________________________________________________________________
# EXPT CASE:  Batch norm- False
# Epoch 1/30
# 16/16 [==============================] - 47s 3s/step - loss: 1.1712 - accuracy: 0.4965 - val_loss: 0.8370 - val_accuracy: 0.5976
# Epoch 2/30
# 16/16 [==============================] - 46s 3s/step - loss: 0.8479 - accuracy: 0.6889 - val_loss: 0.9383 - val_accuracy: 0.6819
# Epoch 3/30
# 16/16 [==============================] - 45s 3s/step - loss: 0.7275 - accuracy: 0.7044 - val_loss: 0.5921 - val_accuracy: 0.8435
# Epoch 4/30
# 16/16 [==============================] - 46s 3s/step - loss: 0.6426 - accuracy: 0.7253 - val_loss: 0.6601 - val_accuracy: 0.7842
# Epoch 5/30
# 16/16 [==============================] - 46s 3s/step - loss: 0.5570 - accuracy: 0.7928 - val_loss: 1.1151 - val_accuracy: 0.6940
# Epoch 6/30
# 16/16 [==============================] - 45s 3s/step - loss: 0.6732 - accuracy: 0.6874 - val_loss: 0.9005 - val_accuracy: 0.6978
# Epoch 7/30
# 16/16 [==============================] - 45s 3s/step - loss: 0.6560 - accuracy: 0.7454 - val_loss: 0.3708 - val_accuracy: 0.8820
# Epoch 8/30
# 16/16 [==============================] - 45s 3s/step - loss: 0.4448 - accuracy: 0.8305 - val_loss: 0.3115 - val_accuracy: 0.8887
# Epoch 9/30
# 16/16 [==============================] - 44s 3s/step - loss: 0.2778 - accuracy: 0.8997 - val_loss: 0.1878 - val_accuracy: 0.9505
# Epoch 10/30
# 16/16 [==============================] - 45s 3s/step - loss: 0.2596 - accuracy: 0.9062 - val_loss: 0.3566 - val_accuracy: 0.8521
# Epoch 11/30
# 16/16 [==============================] - 45s 3s/step - loss: 0.4583 - accuracy: 0.8139 - val_loss: 0.2624 - val_accuracy: 0.9548
# Epoch 12/30
# 16/16 [==============================] - 44s 3s/step - loss: 0.1985 - accuracy: 0.9543 - val_loss: 0.1374 - val_accuracy: 0.9595
# Epoch 13/30
# 16/16 [==============================] - 46s 3s/step - loss: 0.1606 - accuracy: 0.9436 - val_loss: 0.1680 - val_accuracy: 0.9508
# Epoch 14/30
# 16/16 [==============================] - 45s 3s/step - loss: 0.1282 - accuracy: 0.9725 - val_loss: 0.2344 - val_accuracy: 0.9146
# Epoch 15/30
# 16/16 [==============================] - 46s 3s/step - loss: 0.1555 - accuracy: 0.9404 - val_loss: 0.0968 - val_accuracy: 0.9723
# Epoch 16/30
# 16/16 [==============================] - 45s 3s/step - loss: 0.0968 - accuracy: 0.9639 - val_loss: 0.1815 - val_accuracy: 0.9249
# Epoch 17/30
# 16/16 [==============================] - 45s 3s/step - loss: 0.0874 - accuracy: 0.9735 - val_loss: 0.3777 - val_accuracy: 0.8635
# Epoch 18/30
# 16/16 [==============================] - 46s 3s/step - loss: 0.0838 - accuracy: 0.9693 - val_loss: 0.2599 - val_accuracy: 0.8892
# Epoch 19/30
# 16/16 [==============================] - 46s 3s/step - loss: 0.2024 - accuracy: 0.9235 - val_loss: 0.0401 - val_accuracy: 0.9899
# Epoch 20/30
# 16/16 [==============================] - 46s 3s/step - loss: 0.0739 - accuracy: 0.9803 - val_loss: 0.0991 - val_accuracy: 0.9629
# Epoch 21/30
# 16/16 [==============================] - 46s 3s/step - loss: 0.0640 - accuracy: 0.9846 - val_loss: 0.0361 - val_accuracy: 0.9885
# Epoch 22/30
# 16/16 [==============================] - 46s 3s/step - loss: 0.1763 - accuracy: 0.9549 - val_loss: 0.1752 - val_accuracy: 0.9409
# Epoch 23/30
# 16/16 [==============================] - 46s 3s/step - loss: 0.1121 - accuracy: 0.9698 - val_loss: 0.0640 - val_accuracy: 0.9858
# Epoch 24/30
# 16/16 [==============================] - 46s 3s/step - loss: 0.0489 - accuracy: 0.9867 - val_loss: 0.0194 - val_accuracy: 0.9935
# Epoch 25/30
# 16/16 [==============================] - 46s 3s/step - loss: 0.0158 - accuracy: 0.9949 - val_loss: 0.0156 - val_accuracy: 0.9946
# Epoch 26/30
# 16/16 [==============================] - 46s 3s/step - loss: 0.0127 - accuracy: 0.9962 - val_loss: 0.0137 - val_accuracy: 0.9948
# Epoch 27/30
# 16/16 [==============================] - 46s 3s/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.0119 - val_accuracy: 0.9953
# Epoch 28/30
# 16/16 [==============================] - 47s 3s/step - loss: 0.0097 - accuracy: 0.9970 - val_loss: 0.0103 - val_accuracy: 0.9960
# Epoch 29/30
# 16/16 [==============================] - 45s 3s/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0090 - val_accuracy: 0.9966
# Epoch 30/30
# 16/16 [==============================] - 47s 3s/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.0078 - val_accuracy: 0.9973
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 98, 32)            23840
# _________________________________________________________________
# batch_normalization (BatchNo (None, 98, 32)            128
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 96, 32)            3104
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 96, 32)            128
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 48, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 46, 64)            6208
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 46, 64)            256
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 23, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1472)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                94272
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 132,356
# Trainable params: 132,100
# Non-trainable params: 256
# _________________________________________________________________
# EXPT CASE:  Batch norm- True
# Epoch 1/30
# 16/16 [==============================] - 49s 3s/step - loss: 0.7477 - accuracy: 0.7330 - val_loss: 1.3271 - val_accuracy: 0.4179
# Epoch 2/30
# 16/16 [==============================] - 49s 3s/step - loss: 0.4899 - accuracy: 0.8677 - val_loss: 1.1969 - val_accuracy: 0.6315
# Epoch 3/30
# 16/16 [==============================] - 48s 3s/step - loss: 0.1346 - accuracy: 0.9656 - val_loss: 0.9520 - val_accuracy: 0.6871
# Epoch 4/30
# 16/16 [==============================] - 81s 5s/step - loss: 0.0699 - accuracy: 0.9803 - val_loss: 0.8420 - val_accuracy: 0.6079
# Epoch 5/30
# 16/16 [==============================] - 133s 8s/step - loss: 0.0237 - accuracy: 0.9931 - val_loss: 0.5486 - val_accuracy: 0.8750
# Epoch 6/30
# 16/16 [==============================] - 110s 7s/step - loss: 0.0070 - accuracy: 0.9991 - val_loss: 0.4385 - val_accuracy: 0.8824
# Epoch 7/30
# 16/16 [==============================] - 107s 7s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.3624 - val_accuracy: 0.8896
# Epoch 8/30
# 16/16 [==============================] - 101s 6s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2926 - val_accuracy: 0.9218
# Epoch 9/30
# 16/16 [==============================] - 155s 10s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2404 - val_accuracy: 0.9353
# Epoch 10/30
# 16/16 [==============================] - 138s 9s/step - loss: 9.9763e-04 - accuracy: 1.0000 - val_loss: 0.1984 - val_accuracy: 0.9429
# Epoch 11/30
# 16/16 [==============================] - 174s 11s/step - loss: 7.9189e-04 - accuracy: 1.0000 - val_loss: 0.1730 - val_accuracy: 0.9456
# Epoch 12/30
# 16/16 [==============================] - 167s 10s/step - loss: 6.5044e-04 - accuracy: 1.0000 - val_loss: 0.1531 - val_accuracy: 0.9465
# Epoch 13/30
# 16/16 [==============================] - 138s 9s/step - loss: 5.4592e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9463
# Epoch 14/30
# 16/16 [==============================] - 137s 9s/step - loss: 4.6562e-04 - accuracy: 1.0000 - val_loss: 0.1312 - val_accuracy: 0.9451
# Epoch 15/30
# 16/16 [==============================] - 139s 9s/step - loss: 4.0308e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9487
# Epoch 16/30
# 16/16 [==============================] - 138s 9s/step - loss: 3.5269e-04 - accuracy: 1.0000 - val_loss: 0.1354 - val_accuracy: 0.9400
# Epoch 17/30
# 16/16 [==============================] - 138s 9s/step - loss: 3.1151e-04 - accuracy: 1.0000 - val_loss: 0.1237 - val_accuracy: 0.9460
# Epoch 18/30
# 16/16 [==============================] - 142s 9s/step - loss: 2.7762e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.9458
# Epoch 19/30
# 16/16 [==============================] - 133s 8s/step - loss: 2.4829e-04 - accuracy: 1.0000 - val_loss: 0.1265 - val_accuracy: 0.9449
# Epoch 20/30
# 16/16 [==============================] - 125s 8s/step - loss: 2.2426e-04 - accuracy: 1.0000 - val_loss: 0.1269 - val_accuracy: 0.9456
# Epoch 21/30
# 16/16 [==============================] - 118s 7s/step - loss: 2.0368e-04 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 0.9445
# Epoch 22/30
# 16/16 [==============================] - 114s 7s/step - loss: 1.8562e-04 - accuracy: 1.0000 - val_loss: 0.1322 - val_accuracy: 0.9454
# Epoch 23/30
# 16/16 [==============================] - 105s 7s/step - loss: 1.7031e-04 - accuracy: 1.0000 - val_loss: 0.1390 - val_accuracy: 0.9442
# Epoch 24/30
# 16/16 [==============================] - 123s 8s/step - loss: 1.5670e-04 - accuracy: 1.0000 - val_loss: 0.1339 - val_accuracy: 0.9451
# Epoch 25/30
# 16/16 [==============================] - 156s 10s/step - loss: 1.4491e-04 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9449
# Epoch 26/30
# 16/16 [==============================] - 78s 5s/step - loss: 1.3455e-04 - accuracy: 1.0000 - val_loss: 0.1400 - val_accuracy: 0.9454
# Epoch 27/30
# 16/16 [==============================] - 63s 4s/step - loss: 1.2482e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9451
# Epoch 28/30
# 16/16 [==============================] - 47s 3s/step - loss: 1.1653e-04 - accuracy: 1.0000 - val_loss: 0.1430 - val_accuracy: 0.9458
# Epoch 29/30
# 16/16 [==============================] - 46s 3s/step - loss: 1.0907e-04 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 0.9456
# Epoch 30/30
# 16/16 [==============================] - 47s 3s/step - loss: 1.0211e-04 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9465

# %% [markdown]
# ## Experiment 4: Dropout regularization

# %%
# Sweep config
dropout_prob_list = [0.1, 0.15, 0.2]
EPOCHS=50

base_log_dir = "/content/drive/My Drive/DL-final_project/Results/Cross/Expt4-dropout/logs/"

# %%
for dropout_prob in dropout_prob_list:
   # Set up callback
  log_dir = base_log_dir +  "{}_dropout/".format(dropout_prob)
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir, histogram_freq=0, write_graph=True, write_images=False,
      update_freq='epoch', profile_batch=2, embeddings_freq=0,
      embeddings_metadata=None)

  # Initialize data generators
  train_generator = train_val_generator(train_data_dir, 
                                                 'training', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                                 WINDOW_SIZE, WINDOW_SHIFT, 
                                                 maxs_array, mins_array)

  val_generator = train_val_generator(train_data_dir, 
                                               'validation', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                               WINDOW_SIZE, WINDOW_SHIFT, 
                                               maxs_array, mins_array)

  # Initialize model
  model = CNN_model_cross(WINDOW_SIZE,
                    N_CONV_LAYERS, KERNELS, KERNEL_SIZES, 
                    hyper_params={'lr':0.001, 'batch_norm':False, 'dropout_prob':dropout_prob})
  
  # Start training
  print("EXPT CASE: Dropout-", dropout_prob)
  model.fit(train_generator,
              steps_per_epoch = 16,
              validation_data = val_generator,
              validation_steps = 16,
              epochs = EPOCHS,
              callbacks=[tensorboard_callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 98, 32)            23840
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 96, 32)            3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 48, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 46, 64)            6208
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 23, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1472)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                94272
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 131,844
# Trainable params: 131,844
# Non-trainable params: 0
# _________________________________________________________________
# EXPT CAS
step - loss: 0.0086 - accuracy: 0.9975 - val_loss: 0.0062 - val_accuracy: 0.9980
# Epoch 33/50
# 16/16 [==============================] - 133s 8s/step - loss: 0.0062 - accuracy: 0.9985 - val_loss: 0.0053 - val_accuracy: 0.9982
# Epoch 34/50
# 16/16 [==============================] - 138s 9s/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0044 - val_accuracy: 0.9989
# Epoch 35/50
# 16/16 [==============================] - 129s 8s/step - loss: 0.0045 - accuracy: 0.9988 - val_loss: 0.0037 - val_accuracy: 0.9991
# Epoch 36/50
# 16/16 [==============================] - 119s 7s/step - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.0022 - val_accuracy: 0.9996
# Epoch 37/50
# 16/16 [==============================] - 115s 7s/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0020 - val_accuracy: 0.9996
# Epoch 38/50
# 16/16 [==============================] - 116s 7s/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 39/50
# 16/16 [==============================] - 120s 7s/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 40/50
# 16/16 [==============================] - 148s 9s/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 6.3165e-04 - val_accuracy: 1.0000
# Epoch 41/50
# 16/16 [==============================] - 151s 9s/step - loss: 0.0017 - accuracy: 0.9998 - val_loss: 4.2691e-04 - val_accuracy: 1.0000
# Epoch 42/50
# 16/16 [==============================] - 145s 9s/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 3.0887e-04 - val_accuracy: 1.0000
# Epoch 43/50
# 16/16 [==============================] - 151s 9s/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 2.5717e-04 - val_accuracy: 1.0000
# Epoch 44/50
# 16/16 [==============================] - 157s 10s/step - loss: 9.3658e-04 - accuracy: 0.9999 - val_loss: 2.3793e-04 - val_accuracy: 1.0000
# Epoch 45/50
# 16/16 [==============================] - 164s 10s/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 1.7140e-04 - val_accuracy: 1.0000
# Epoch 46/50
# 16/16 [==============================] - 143s 9s/step - loss: 6.2899e-04 - accuracy: 1.0000 - val_loss: 1.4910e-04 - val_accuracy: 1.0000
# Epoch 47/50
# 16/16 [==============================] - 137s 9s/step - loss: 5.2752e-04 - accuracy: 1.0000 - val_loss: 1.1227e-04 - val_accuracy: 1.0000
# Epoch 48/50
# 16/16 [==============================] - 137s 9s/step - loss: 4.8859e-04 - accuracy: 0.9999 - val_loss: 1.0749e-04 - val_accuracy: 1.0000
# Epoch 49/50
# 16/16 [==============================] - 136s 8s/step - loss: 5.6652e-04 - accuracy: 1.0000 - val_loss: 8.3678e-05 - val_accuracy: 1.0000
# Epoch 50/50
# 16/16 [==============================] - 140s 9s/step - loss: 3.2120e-04 - accuracy: 1.0000 - val_loss: 7.3372e-05 - val_accuracy: 1.0000

# %% [markdown]
# ## Experiment 5: Learning rate tuning

# %%
# Sweep config
learning_rate_list = [0.005, 0.007, 0.01]
EPOCHS=40

base_log_dir = "/content/drive/My Drive/DL-final_project/Results/Cross/Expt5-learningRate/logs/"

# %%
for i, learning_rate in enumerate(learning_rate_list):
  # Set up callback
  log_dir = base_log_dir +  "{}_learningRate/".format(learning_rate)
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir, histogram_freq=0, write_graph=True, write_images=False,
      update_freq='epoch', profile_batch=2, embeddings_freq=0,
      embeddings_metadata=None)

  # Initialize data generators
  train_generator = train_val_generator(train_data_dir, 
                                                 'training', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                                 WINDOW_SIZE, WINDOW_SHIFT, 
                                                 maxs_array, mins_array)

  val_generator = train_val_generator(train_data_dir, 
                                               'validation', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                               WINDOW_SIZE, WINDOW_SHIFT, 
                                               maxs_array, mins_array)

  # Initialize model
  model = CNN_model_cross(WINDOW_SIZE,
                    N_CONV_LAYERS, KERNELS, KERNEL_SIZES, 
                    hyper_params={'lr':learning_rate, 'batch_norm':False, 'dropout_prob':0.0})
  
  # Start training
  print("\nEXPT CASE: Learning rate-", learning_rate)
  model.fit(train_generator,
              steps_per_epoch = 16,
              validation_data = val_generator,
              validation_steps = 16,
              epochs = EPOCHS,
              callbacks=[tensorboard_callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 98, 32)            23840
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 96, 32)            3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 48, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 46, 64)            6208
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 23, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1472)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                94272
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 131,844
# Trainable params: 131,844
# Non-trainable params: 0
# _________________________________________________________________
#
# EXPT CASE: Learning rate- 0.007
# Epoch 1/40
# WARNING:tensorflow:Trace already enabled
# WARNING:tensorflow:Trace already enabled
# 16/16 [==============================] - 220s 14s/step - loss: 1.3560 - accuracy: 0.3731 - val_loss: 1.0856 - val_accuracy: 0.4822
# Epoch 2/40
# 16/16 [==============================] - 216s 13s/step - loss: 1.0550 - accuracy: 0.4638 - val_loss: 0.9603 - val_accuracy: 0.4820
# Epoch 3/40
# 16/16 [==============================] - 215s 13s/step - loss: 1.3262 - accuracy: 0.3586 - val_loss: 1.3284 - val_accuracy: 0.2579
# Epoch 4/40
# 16/16 [==============================] - 226s 14s/step - loss: 1.3140 - accuracy: 0.3615 - val_loss: 1.2264 - val_accuracy: 0.4308
# Epoch 5/40
# 16/16 [==============================] - 203s 13s/step - loss: 1.1150 - accuracy: 0.4983 - val_loss: 0.9643 - val_accuracy: 0.4373
# Epoch 6/40
# Epoch 29/40
# 16/16 [==============================] - 41s 3s/step - loss: 1.1923 - accuracy: 0.4050 - val_loss: 1.2929 - val_accuracy: 0.3831
# Epoch 30/40
# 16/16 [==============================] - 41s 3s/step - loss: 1.0724 - accuracy: 0.4450 - val_loss: 1.0791 - val_accuracy: 0.4827
# Epoch 31/40
# 16/16 [==============================] - 41s 3s/step - loss: 1.0970 - accuracy: 0.4354 - val_loss: 0.9448 - val_accuracy: 0.4820
# Epoch 32/40
# 16/16 [==============================] - 42s 3s/step - loss: 0.9607 - accuracy: 0.5493 - val_loss: 0.9447 - val_accuracy: 0.5528
# Epoch 33/40
# 16/16 [==============================] - 42s 3s/step - loss: 0.9200 - accuracy: 0.5128 - val_loss: 0.8776 - val_accuracy: 0.6041
# Epoch 34/40
# 16/16 [==============================] - 42s 3s/step - loss: 0.8683 - accuracy: 0.6957 - val_loss: 0.8477 - val_accuracy: 0.7203
# Epoch 35/40
# 16/16 [==============================] - 42s 3s/step - loss: 0.8430 - accuracy: 0.6064 - val_loss: 0.8376 - val_accuracy: 0.6536
# Epoch 36/40
# 16/16 [==============================] - 42s 3s/step - loss: 0.8622 - accuracy: 0.5658 - val_loss: 0.8523 - val_accuracy: 0.5333
# Epoch 37/40
# 16/16 [==============================] - 41s 3s/step - loss: 0.7980 - accuracy: 0.6550 - val_loss: 0.8097 - val_accuracy: 0.6079
# Epoch 38/40
# 16/16 [==============================] - 42s 3s/step - loss: 0.7358 - accuracy: 0.6547 - val_loss: 0.7779 - val_accuracy: 0.6450
# Epoch 39/40
# 16/16 [==============================] - 41s 3s/step - loss: 0.8911 - accuracy: 0.5493 - val_loss: 0.7403 - val_accuracy: 0.6331
# Epoch 40/40
# 16/16 [==============================] - 41s 3s/step - loss: 0.6940 - accuracy: 0.6551 - val_loss: 0.7770 - val_accuracy: 0.6428

# %% [markdown]
# ## Experiment 6: Weight initialization

# %%
# Sweep config

initializer_list = ['glorot_normal', 
                    'zeros', 
                    'random_normal',
                    'random_uniform']

EPOCHS=30

base_log_dir = "/content/drive/My Drive/DL-final_project/Results/Cross/Expt6-weightInit/logs/"

# %%
for initializer in initializer_list:
     # Set up callback
  log_dir = base_log_dir +  "{}_weightInit/".format(initializer)
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir, histogram_freq=0, write_graph=True, write_images=False,
      update_freq='epoch', profile_batch=2, embeddings_freq=0,
      embeddings_metadata=None)

  # Initialize data generators
  train_generator = train_val_generator(train_data_dir, 
                                                 'training', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                                 WINDOW_SIZE, WINDOW_SHIFT, 
                                                 maxs_array, mins_array)

  val_generator = train_val_generator(train_data_dir, 
                                               'validation', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                               WINDOW_SIZE, WINDOW_SHIFT, 
                                               maxs_array, mins_array)

  # Initialize model
  model = CNN_model_cross(WINDOW_SIZE,
                    N_CONV_LAYERS, KERNELS, KERNEL_SIZES, 
                    HYPER_PARAMS,
                    initializer)
  
  # Start training
  print("\nEXPT CASE: Initializer-", initializer)
  model.fit(train_generator,
              steps_per_epoch = 16,
              validation_data = val_generator,
              validation_steps = 16,
              epochs = EPOCHS,
              callbacks=[tensorboard_callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 98, 32)            23840
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 96, 32)            3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 48, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 46, 64)            6208
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 23, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1472)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                94272
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 131,844
# Trainable params: 131,844
# Non-trainable params: 0
# _________________________________________________________________
#
# EXPT CASE: Initializer- zeros
# Epoch 1/30
# 16/16 [==============================] - 202s 13s/step - loss: 1.3863 - accuracy: 0.2525 - val_loss: 1.3864 - val_accuracy: 0.2415
# Epoch 2/30
# 16/16 [==============================] - 193s 12s/step - loss: 1.3863 - accuracy: 0.2525 - val_loss: 1.3865 - val_accuracy: 0.2415
# Epoch 3/30
# 16/16 [==============================] - 131s 8s/step - loss: 1.3863 - accuracy: 0.2527 - val_loss: 1.3865 - val_accuracy: 0.2401
# Epoch 4/30
# 16/16 [==============================] - 69s 4s/step - loss: 1.3863 - accuracy: 0.2523 - val_loss: 1.3865 - val_accuracy: 0.2417
# Epoch 5/30
# 16/16 [==============================] - 39s 2s/step - loss: 1.3863 - accuracy: 0.2526 - val_loss: 1.3866 - val_accuracy: 0.2358
# Epoch 6/30
# 16/16 [==============================] - 39s 2s/step - loss: 1.3863 - accuracy: 0.
# Epoch 20/30
# 16/16 [==============================] - 187s 12s/step - loss: 0.2843 - accuracy: 0.8810 - val_loss: 0.1688 - val_accuracy: 0.9789
# Epoch 21/30
# 16/16 [==============================] - 179s 11s/step - loss: 0.1569 - accuracy: 0.9624 - val_loss: 0.1131 - val_accuracy: 0.9699
# Epoch 22/30
# 16/16 [==============================] - 149s 9s/step - loss: 0.1188 - accuracy: 0.9635 - val_loss: 0.2204 - val_accuracy: 0.8961
# Epoch 23/30
# 16/16 [==============================] - 114s 7s/step - loss: 0.2801 - accuracy: 0.9044 - val_loss: 0.7921 - val_accuracy: 0.7750
# Epoch 24/30
# 16/16 [==============================] - 136s 8s/step - loss: 0.5151 - accuracy: 0.8498 - val_loss: 0.3153 - val_accuracy: 0.9548
# Epoch 25/30
# 16/16 [==============================] - 42s 3s/step - loss: 0.1746 - accuracy: 0.9775 - val_loss: 0.1293 - val_accuracy: 0.9415
# Epoch 26/30
# 16/16 [==============================] - 37s 2s/step - loss: 0.1092 - accuracy: 0.9662 - val_loss: 0.1091 - val_accuracy: 0.9609
# Epoch 27/30
# 16/16 [==============================] - 38s 2s/step - loss: 0.0556 - accuracy: 0.9884 - val_loss: 0.0450 - val_accuracy: 0.9888
# Epoch 28/30
# 16/16 [==============================] - 38s 2s/step - loss: 0.0740 - accuracy: 0.9755 - val_loss: 0.0711 - val_accuracy: 0.9782
# Epoch 29/30
# 16/16 [==============================] - 38s 2s/step - loss: 0.0843 - accuracy: 0.9717 - val_loss: 0.0797 - val_accuracy: 0.9753
# Epoch 30/30
# 16/16 [==============================] - 37s 2s/step - loss: 0.1382 - accuracy: 0.9570 - val_loss: 0.1680 - val_accuracy: 0.9321

# %% [markdown]
# ## Best model

# %%
# Config
hyper_params_best = {'lr':0.001, 'batch_norm':False, 'dropout_prob':0.15}
n_conv_layers_best = 3
kernels_best = [32,32,64]
kernel_sizes_best = [3,3,3]

initializer_best = 'glorot_uniform'

epochs_best = 50

log_dir_best = "/content/drive/My Drive/DL-final_project/Results/Cross/BestModel/logs/"

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir_best, histogram_freq=0, write_graph=True, write_images=False,
                                                      update_freq='epoch', profile_batch=2, embeddings_freq=0,
                                                      embeddings_metadata=None)

# Initialize data generators
train_generator = train_val_generator(train_data_dir, 
                                      'training', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                      WINDOW_SIZE, WINDOW_SHIFT, 
                                      maxs_array, mins_array)

val_generator = train_val_generator(train_data_dir, 
                                    'validation', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                    WINDOW_SIZE, WINDOW_SHIFT, 
                                    maxs_array, mins_array)

# Initialize model
best_model = CNN_model_cross(WINDOW_SIZE,
                            n_conv_layers_best, kernels_best, kernel_sizes_best, 
                            hyper_params_best,
                            initializer_best)

# Start training
best_model.fit(train_generator,
            steps_per_epoch = 16,
            validation_data = val_generator,
            validation_steps = 16,
            epochs = epochs_best,
            callbacks=[tensorboard_callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 98, 32)            23840
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 96, 32)            3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 48, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 46, 64)            6208
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 23, 64)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1472)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                94272
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 131,844
# Trainable params: 131,844
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#
50
# 16/16 [==============================] - 35s 2s/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 0.0558 - val_accuracy: 0.9840
# Epoch 33/50
# 16/16 [==============================] - 36s 2s/step - loss: 0.0359 - accuracy: 0.9877 - val_loss: 0.0087 - val_accuracy: 0.9960
# Epoch 34/50
# 16/16 [==============================] - 36s 2s/step - loss: 0.4942 - accuracy: 0.9347 - val_loss: 0.1340 - val_accuracy: 0.9607
# Epoch 35/50
# 16/16 [==============================] - 36s 2s/step - loss: 0.3311 - accuracy: 0.8832 - val_loss: 0.5194 - val_accuracy: 0.8530
# Epoch 36/50
# 16/16 [==============================] - 35s 2s/step - loss: 0.4175 - accuracy: 0.8451 - val_loss: 0.3370 - val_accuracy: 0.9119
# Epoch 37/50
# 16/16 [==============================] - 35s 2s/step - loss: 0.2127 - accuracy: 0.9405 - val_loss: 0.1009 - val_accuracy: 0.9741
# Epoch 38/50
# 16/16 [==============================] - 35s 2s/step - loss: 0.0779 - accuracy: 0.9767 - val_loss: 0.1304 - val_accuracy: 0.9595
# Epoch 39/50
# 16/16 [==============================] - 35s 2s/step - loss: 0.0405 - accuracy: 0.9918 - val_loss: 0.0242 - val_accuracy: 0.9910
# Epoch 40/50
# 16/16 [==============================] - 36s 2s/step - loss: 0.0177 - accuracy: 0.9928 - val_loss: 0.0112 - val_accuracy: 0.9955
# Epoch 41/50
# 16/16 [==============================] - 36s 2s/step - loss: 0.0103 - accuracy: 0.9970 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 42/50
# 16/16 [==============================] - 35s 2s/step - loss: 0.0052 - accuracy: 0.9998 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 43/50
# 16/16 [==============================] - 36s 2s/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 44/50
# 16/16 [==============================] - 36s 2s/step - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 45/50
# 16/16 [==============================] - 36s 2s/step - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 46/50
# 16/16 [==============================] - 36s 2s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 8.2788e-04 - val_accuracy: 1.0000
# Epoch 47/50
# 16/16 [==============================] - 35s 2s/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 6.3438e-04 - val_accuracy: 1.0000
# Epoch 48/50
# 16/16 [==============================] - 35s 2s/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 5.0641e-04 - val_accuracy: 1.0000
# Epoch 49/50
# 16/16 [==============================] - 38s 2s/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 4.4234e-04 - val_accuracy: 1.0000
# Epoch 50/50
# 16/16 [==============================] - 37s 2s/step - loss: 9.3562e-04 - accuracy: 0.9999 - val_loss: 3.6070e-04 - val_accuracy: 1.0000

# %%
# Save
#print("Saving...")
#best_model.save("/content/drive/My Drive/DL-final_project/Saved models/best_model_cross.h5")

tf.keras.utils.plot_model(best_model, 
                          to_file='/content/drive/My Drive/DL-final_project/Results/Cross/BestModel/bestmodel_arch.png', 
                          show_shapes=True, show_layer_names=False,
                          rankdir='TB', expand_nested=False, dpi=96)

# %% [markdown]
# #### Evaluating the best model

# %%
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
import seaborn as sn


# Load model
#print("Loading model...")
#best_model = tf.keras.models.load_model("/content/drive/My Drive/DL-final_project/Saved models/best_model_cross.h5")

print("Evaluating...")
test_data_base_dir = "/content/drive/My Drive/DL-final_project/Data/Cross/"

# Test set 1 ########################################################################
test_gen_1 = test_generator(test_data_base_dir+"test1/", 
                                downsampling_factor=DOWNSAMPLING_FACTOR, 
                                window_size=WINDOW_SIZE, 
                                window_shift=WINDOW_SHIFT, 
                                maxs_array=maxs_array, 
                                mins_array=mins_array)

print("On Test Set 1 -----------------------------------------------------------")
best_model.evaluate(test_gen_1,
                    steps=16)

Y_test_true = []
Y_test_pred = []
for i in range(16):
  X_test, Y_test = next(test_gen_1)
  Y_pred = best_model.predict(X_test)
  Y_pred = np.argmax(Y_pred, axis=1)

  Y_test_true.extend(Y_test.tolist())
  Y_test_pred.extend(Y_pred.tolist())

Y_test_true = np.array(Y_test_true)
Y_test_pred = np.array(Y_test_pred)

accuracy = np.mean(np.equal(Y_test_true,Y_test_pred))
print("Accuracy:", accuracy)

confusion_matrix = metrics.confusion_matrix(Y_test_true, Y_test_pred)

fig, ax= plt.subplots()
fig.set_size_inches(0.7*18.5, 0.8*10.5)
fig.set_dpi(200)
sn.heatmap(confusion_matrix/np.sum(confusion_matrix), annot=True, 
            fmt='.2%', cmap='gist_heat')
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
labels = ["Rest", "Motor", "Story, math", "Working memory"]
ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)
fig.savefig("/content/drive/My Drive/DL-final_project/Results/Cross/BestModel/bestModel_CM_test1.png")
plt.show()

# Test set 2 ########################################################################
test_gen_2 = test_generator(test_data_base_dir+"test2/", 
                                downsampling_factor=DOWNSAMPLING_FACTOR, 
                                window_size=WINDOW_SIZE, 
                                window_shift=WINDOW_SHIFT, 
                                maxs_array=maxs_array, 
                                mins_array=mins_array)

print("On test set 2 -----------------------------------------------------------")
best_model.evaluate(test_gen_2,
                    steps=16)

Y_test_true = []
Y_test_pred = []
for i in range(16):
  X_test, Y_test = next(test_gen_2)
  Y_pred = best_model.predict(X_test)
  Y_pred = np.argmax(Y_pred, axis=1)

  Y_test_true.extend(Y_test.tolist())
  Y_test_pred.extend(Y_pred.tolist())

Y_test_true = np.array(Y_test_true)
Y_test_pred = np.array(Y_test_pred)

accuracy = np.mean(np.equal(Y_test_true,Y_test_pred))
print("Accuracy:", accuracy)

confusion_matrix = metrics.confusion_matrix(Y_test_true, Y_test_pred)

fig, ax= plt.subplots()
fig.set_size_inches(0.7*18.5, 0.8*10.5)
fig.set_dpi(200)
sn.heatmap(confusion_matrix/np.sum(confusion_matrix), annot=True, 
            fmt='.2%', cmap='gist_heat')
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
labels = ["Rest", "Motor", "Story, math", "Working memory"]
ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)
fig.savefig("/content/drive/My Drive/DL-final_project/Results/Cross/BestModel/bestModel_CM_test2.png")
plt.show()

# Test set 3 ########################################################################
test_gen_3 = test_generator(test_data_base_dir+"test3/", 
                                downsampling_factor=DOWNSAMPLING_FACTOR, 
                                window_size=WINDOW_SIZE, 
                                window_shift=WINDOW_SHIFT, 
                                maxs_array=maxs_array, 
                                mins_array=mins_array)

print("On test set 3 -----------------------------------------------------------")
best_model.evaluate(test_gen_3,
                    steps=16)

Y_test_true = []
Y_test_pred = []
for i in range(16):
  X_test, Y_test = next(test_gen_3)
  Y_pred = best_model.predict(X_test)
  Y_pred = np.argmax(Y_pred, axis=1)

  Y_test_true.extend(Y_test.tolist())
  Y_test_pred.extend(Y_pred.tolist())

Y_test_true = np.array(Y_test_true)
Y_test_pred = np.array(Y_test_pred)

accuracy = np.mean(np.equal(Y_test_true,Y_test_pred))
print("Accuracy:", accuracy)

confusion_matrix = metrics.confusion_matrix(Y_test_true, Y_test_pred)

fig, ax= plt.subplots()
fig.set_size_inches(0.7*18.5, 0.8*10.5)
fig.set_dpi(200)
sn.heatmap(confusion_matrix/np.sum(confusion_matrix), annot=True, 
            fmt='.2%', cmap='gist_heat')
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
labels = ["Rest", "Motor", "Story, math", "Working memory"]
ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)
fig.savefig("/content/drive/My Drive/DL-final_project/Results/Cross/BestModel/bestModel_CM_test3.png")
plt.show()
# Out:
# Loading model...
# Evaluating...
# On Test Set 1 -----------------------------------------------------------
# 16/16 [==============================] - 72s 5s/step - loss: 2.6047 - accuracy: 0.9038
# Accuracy: 0.9038184438040345
# On test set 2 -----------------------------------------------------------
# 16/16 [==============================] - 76s 5s/step - loss: 5.4414 - accuracy: 0.8019
# Accuracy: 0.8018731988472623
# On test set 3 -----------------------------------------------------------
# 16/16 [==============================] - 74s 5s/step - loss: 2.5323 - accuracy: 0.8174
# Accuracy: 0.8173631123919308
