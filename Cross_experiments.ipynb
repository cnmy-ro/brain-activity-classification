# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
import sys
import h5py
import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf
from tensorflow.keras import datasets, layers, models

np.random.seed(0)

# %% [markdown]
# ### Data utils

# %%
def get_dataset_name(file_name_with_dir):
    filename_without_dir = file_name_with_dir.split('/')[-1]
    temp = filename_without_dir.split('_')[:-1]
    dataset_name = "_".join(temp)
    return dataset_name


def normalize(matrix, class_id, maxs_array, mins_array):
  maxs = maxs_array[:, class_id]
  maxs = maxs.reshape(maxs.shape[0],1)
  mins = mins_array[:, class_id]
  mins = mins.reshape(mins.shape[0],1)
  return (matrix-mins)/(maxs-mins)

def subsample(matrix, downsampling_factor=10):
  return matrix[:, ::downsampling_factor]

# %% [markdown]
# ### Data generators

# %%
def train_val_generator(train_data_dir, mode='training', downsampling_factor=10, val_split=0.2, shuffle=False, window_size=1000, window_shift=50, maxs_array=None, mins_array=None):
  '''
  Generate 4 chunk, one one class
  '''
  
  class_names=['rest', 'task_motor', 'task_story_math', 'task_working_memory']
  
  subject_id_list = [113922, 164636]
  sub_idx = 0
  chunk_id = 1

  while True:
      
    np.random.seed(chunk_id)
    
    # Initialize the dataset
    data_X = []
    data_Y = []

    subject_id = subject_id_list[sub_idx]

    for class_id, class_name in enumerate(class_names):
      filename_path = train_data_dir + '/' + class_name + '_' + str(subject_id) + '_' + str(chunk_id) + '.h5'

      ### Supplied code
      with h5py.File(filename_path,'r') as f:
        dataset_name = get_dataset_name(filename_path)
        matrix = f.get(dataset_name)[()]
      ###

      matrix = normalize(matrix, class_id, maxs_array, mins_array)
      matrix = subsample(matrix, downsampling_factor)
      matrix = matrix.T
      for i in range(window_size-1, matrix.shape[0], window_shift):
        x_instance = matrix[i-window_size+1: i+1, :]
        data_X.append(x_instance)
        data_Y.append(class_id)


    data_X = np.asarray(data_X)
    data_X = data_X.astype(np.float16)
    data_Y = np.asarray(data_Y).astype(np.int8)


    # Shuffle
    if shuffle:
      indices = np.arange(data_X.shape[0])
      np.random.shuffle(indices)
      data_X = data_X[indices,:,:]
      data_Y = data_Y[indices]
        
    n_instances = data_X.shape[0]
    n_instances_train = round((1-val_split)*n_instances)
    
    if mode == 'training':
      # Take first 'n_instances_train' instances of the dataset
      print("\nYielding: Chunk {} (training)".format(chunk_id))
      yield data_X[:n_instances_train,:,:], data_Y[:n_instances_train]


    if mode == 'validation':
      # Take the remaining instances as validation set
      yield data_X[n_instances_train:,:,:], data_Y[n_instances_train:]


    chunk_id += 1
    if chunk_id > 8:
      chunk_id = 1

      sub_idx += 1
      if sub_idx > 1:
        sub_idx = 0

      #raise Exception("All files yielded")
  

def test_generator(test_data_dir, subject_id, downsampling_factor=10, window_size=1000, window_shift=50, maxs_array=None, mins_array=None):
  '''
  Generate 4 chunk, one one class
  '''
  
  class_names=['rest','task_motor','task_story_math','task_working_memory']

  file_names = sorted(os.listdir(test_data_dir))

  while True:

    for file_name in file_names:
      # Initialize the dataset
      test_data_X = []
      test_data_Y = []
      
      filename_path = test_data_dir + file_name
      class_name = file_name.split('_')[:-2]
      class_id = class_names.index(class_name)

      ### Supplied code
      with h5py.File(filename_path,'r') as f:
        dataset_name = get_dataset_name(filename_path)
        matrix = f.get(dataset_name)[()]
      ###

      matrix = normalize(matrix, class_id, maxs_array, mins_array)
      matrix = subsample(matrix, downsampling_factor)
      matrix = matrix.T
      for i in range(window_size-1, matrix.shape[0], window_shift):
        x_instance = matrix[i-window_size+1: i+1, :]
        test_data_X.append(x_instance)
        test_data_Y.append(class_id)

      test_data_X = np.asarray(test_data_X).astype(np.float16)
      test_data_Y = np.asarray(test_data_Y).astype(np.int8)

      # print("Yielding chunk set: ",chunk_id)
      yield test_data_X, test_data_Y

# %% [markdown]
# ### Configuration

# %%
# CROSS train 

train_data_dir = "/content/drive/My Drive/DL-final_project/Data/Cross/train/"
cross_base_dir = "/content/drive/My Drive/DL-final_project/Data/Cross"

train_subject_id_list = [113922, 164636]

class_names = ['rest', 'task_motor', 'task_story_math', 'task_working_memory']
n_sensors = 248        # FIXED: No. of features (sensors) in the signal
steps_per_file = 35624 # FIXED


# Data preprocessing params
DOWNSAMPLING_FACTOR = 10
WINDOW_SIZE = 100
WINDOW_SHIFT = 10
VAL_SPLIT = 0.2
SHUFFLE = True

# Baseline hyper-params
HYPER_PARAMS = {'lr': 0.001, 'batch_norm':False, 'dropout_prob':0.0}
N_CONV_LAYERS = 3
KERNELS = [32,32,64]
KERNEL_SIZES = [3,3,3]

# Training
EPOCHS = 50

# Normalization stuff
maxs_file_path = "/content/drive/My Drive/DL-final_project/data_stats/cross_train_maxs.txt"
mins_file_path = "/content/drive/My Drive/DL-final_project/data_stats/cross_train_mins.txt"
maxs_array = np.loadtxt(maxs_file_path, delimiter=',')
mins_array = np.loadtxt(mins_file_path, delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-0cc7322fcdf9> in <module>()
#      30 maxs_file_path = "/content/drive/My Drive/DL-final_project/data_stats/cross_train_maxs.txt"
#      31 mins_file_path = "/content/drive/My Drive/DL-final_project/data_stats/cross_train_mins.txt"
# ---> 32 maxs_array = np.loadtxt(maxs_file_path, delimiter=',')
#      33 mins_array = np.loadtxt(mins_file_path, delimiter=',')
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     979             fname = os_fspath(fname)
#     980         if _is_string_like(fname):
# --> 981             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     982             fencoding = getattr(fh, 'encoding', 'latin1')
#     983             fh = iter(fh)
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
#     268     ds = DataSource(destpath)
# --> 269     return ds.open(path, mode, encoding=encoding, newline=newline)
#     270
#     271
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     621                                       encoding=encoding, newline=newline)
#     622         else:
# --> 623             raise IOError("%s not found." % path)
#     624
#     625
#
# OSError: /content/drive/My Drive/DL-final_project/data_stats/cross_train_maxs.txt not found.

# %% [markdown]
# ### Model definition

# %%
def CNN_model_cross(window_size, n_conv_layers, kernels, kernel_sizes, hyper_params={'lr':0.001, 'batch_norm':False, 'dropout_prob':0.0}, initializer='glorot_uniform'):
    tf.random.set_seed(0)
    tf.keras.backend.clear_session()

    model = models.Sequential()
    model.add(layers.Conv1D(filters=kernels[0], kernel_size=kernel_sizes[0], strides=1, 
                            activation='relu', 
                            kernel_initializer=initializer,
                            input_shape=(window_size, 248)))

    # model.add(layers.MaxPooling1D(pool_size=2))

    if hyper_params['batch_norm']:
      model.add(layers.BatchNormalization())

    for i in range(1, n_conv_layers):
        model.add(layers.Conv1D(filters=kernels[i], kernel_size=kernel_sizes[i], strides=1, activation='relu', kernel_initializer=initializer))
        model.add(layers.MaxPooling1D(pool_size=2))
        if hyper_params['batch_norm']:
          model.add(layers.BatchNormalization())
    
    model.add(layers.Flatten())

    model.add(layers.Dense(units=64, activation='relu', kernel_initializer=initializer))
    model.add(layers.Dropout(hyper_params['dropout_prob']))

    model.add(layers.Dense(units=64, activation='relu', kernel_initializer=initializer))
    model.add(layers.Dropout(hyper_params['dropout_prob']))

    model.add(layers.Dense(units=4, activation='softmax'))

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hyper_params['lr']),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()
    return model

# %% [markdown]
# ## Experiment 1: Number of Layers

# %%
# Sweep config

n_conv_layers_list = [3, 4, 5, 6]
kernels_list = [[32,32,64],
                [32,32,64,64],
                [32,32,64,64,128],
                [32,32,64,64,128,256]]
kernel_sizes_list = [[3,3,3],
                     [3,3,3,3],
                     [3,3,3,3,3],
                     [3,3,3,3,3,3]]


# Callback config
base_log_dir = "/content/drive/My Drive/DL-final_project/Results/Cross/Expt1-nLayers/logs/"

# %%
for i, n_conv_layers in enumerate(n_conv_layers_list):
  # Set up callback
  log_dir = base_log_dir + str(n_conv_layers) + "_layer/"
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir, histogram_freq=0, write_graph=True, write_images=False,
      update_freq='epoch', profile_batch=2, embeddings_freq=0,
      embeddings_metadata=None)

  # Initialize data generators
  train_generator = train_val_generator(train_data_dir, subject_id, 
                                                 'training', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                                 WINDOW_SIZE, WINDOW_SHIFT, 
                                                 maxs_array, mins_array)

  val_generator = train_val_generator(train_data_dir, subject_id, 
                                               'validation', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                               WINDOW_SIZE, WINDOW_SHIFT, 
                                               maxs_array, mins_array)

  # Initialize model
  kernels = kernels_list[i]
  kernel_sizes = kernel_sizes_list[i]
  model = CNN_model_cross(WINDOW_SIZE,
                    n_conv_layers, kernels, kernel_sizes, 
                    HYPER_PARAMS)
  
  # Start training
  print("EXPT CASE: N Conv Layers-", n_conv_layers)
  model.fit(train_generator,
              steps_per_epoch = 8,
              validation_data = val_generator,
              validation_steps = 8,
              epochs = EPOCHS,
              callbacks=[tensorboard_callback])

# %% [markdown]
# ## Experiment 2: Kernel sizes

# %%
# Baseline config
N_CONV_LAYERS=3
KERNELS=[32,32,64]

# Sweep config
kernel_sizes_list = [[3,3,3],
                    [5,3,3],
                    [5,5,3],
                    [7,3,3],
                    [7,5,3]]

# Callback config
base_log_dir = "/content/drive/My Drive/DL-final_project/Results/Cross/Expt2-kernelSize/logs/"

# %%
for i, kernel_sizes in enumerate(kernel_sizes_list):
  # Set up callback
  log_dir = base_log_dir +  "{}-{}-{}_kernelSize/".format(kernel_sizes[0], kernel_sizes[1], kernel_sizes[2])
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir, histogram_freq=0, write_graph=True, write_images=False,
      update_freq='epoch', profile_batch=2, embeddings_freq=0,
      embeddings_metadata=None)

  # Initialize data generators
  train_generator = train_val_generator(train_data_dir, subject_id, 
                                                 'training', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                                 WINDOW_SIZE, WINDOW_SHIFT, 
                                                 maxs_array, mins_array)

  val_generator = train_val_generator(train_data_dir, subject_id, 
                                               'validation', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                               WINDOW_SIZE, WINDOW_SHIFT, 
                                               maxs_array, mins_array)

  # Initialize model
  model = CNN_model_cross(WINDOW_SIZE,
                    N_CONV_LAYERS, KERNELS, kernel_sizes, 
                    HYPER_PARAMS)
  
  # Start training
  print("EXPT CASE:  Kernel sizes-", kernel_sizes)
  model.fit(train_generator,
              steps_per_epoch = 8,
              validation_data = val_generator,
              validation_steps = 8,
              epochs = EPOCHS,
              callbacks=[tensorboard_callback])

# %% [markdown]
# ## Experiment 3: Batch normalization

# %%
# Callback config
base_log_dir = "/content/drive/My Drive/DL-final_project/Results/Cross/Expt3-batchNorm/logs/"

for batch_norm in [False, True]:

  # Set up callback
  log_dir = base_log_dir +  "{}_batchNorm/".format(int(batch_norm))
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir, histogram_freq=0, write_graph=True, write_images=False,
      update_freq='epoch', profile_batch=2, embeddings_freq=0,
      embeddings_metadata=None)

  # Initialize data generators
  train_generator = train_val_generator(train_data_dir, subject_id, 
                                                 'training', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                                 WINDOW_SIZE, WINDOW_SHIFT, 
                                                 maxs_array, mins_array)

  val_generator = train_val_generator(train_data_dir, subject_id, 
                                               'validation', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                               WINDOW_SIZE, WINDOW_SHIFT, 
                                               maxs_array, mins_array)

  # Initialize model
  model = CNN_model_cross(WINDOW_SIZE,
                    N_CONV_LAYERS, KERNELS, KERNEL_SIZES, 
                    hyper_params={'lr':0.001, 'batch_norm':batch_norm, 'dropout_prob':0.0})
  
  # Start training
  print("EXPT CASE:  Batch norm-", batch_norm)
  model.fit(train_generator,
              steps_per_epoch = 8,
              validation_data = val_generator,
              validation_steps = 8,
              epochs = EPOCHS,
              callbacks=[tensorboard_callback])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 98, 32)            23840
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 96, 32)            3104
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 48, 32)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 46, 64)            6208
# _________________________________________________________________
# flatten (Flatten)            (None, 2944)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               376960
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 418,628
# Trainable params: 418,628
# Non-trainable params: 0
# _________________________________________________________________
# EXPT CASE: 4
#
# Yielding: Chunk 1 (training)
# Epoch 1/50
# 1/8 [==>...........................] - ETA: 0s - loss: 1.3923 - accuracy: 0.3991
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 5s - loss: 1.3650 - accuracy: 0.4396
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 4s - loss: 1.3238 - accuracy: 0.4916
# Yielding: Chunk 4 (training)
# 4/8 [==============>...............] - ETA: 4s - loss: 1.3073 - accuracy: 0.4768
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 3s - loss:
- accuracy: 1.0000
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 7s - loss: 0.0057 - accuracy: 1.0000
# Yielding: Chunk 6 (training)
# 6/8 [=====================>........] - ETA: 7s - loss: 0.0126 - accuracy: 0.9970
# Yielding: Chunk 7 (training)
# 7/8 [=========================>....] - ETA: 3s - loss: 0.0164 - accuracy: 0.9956
# Yielding: Chunk 8 (training)
# 8/8 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9956
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 85s 11s/step - loss: 0.0163 - accuracy: 0.9956 - val_loss: 0.0102 - val_accuracy: 0.9978
# Epoch 46/50
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 11s - loss: 0.0046 - accuracy: 1.0000
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 17s - loss: 0.0038 - accuracy: 1.0000
# Yielding: Chunk 4 (training)
# ...
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 21s 3s/step - loss: 9.5537e-05 - accuracy: 1.0000 - val_loss: 0.0672 - val_accuracy: 0.9807
# Epoch 36/50
# 1/8 [==>...........................] - ETA: 0s - loss: 6.5386e-05 - accuracy: 1.0000
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 4s - loss: 4.3751e-05 - accuracy: 1.0000
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 4s - loss: 5.2753e-05 - accuracy: 1.0000
# Yielding: Chunk 4 (training)
# 4/8 [==============>...............] - ETA: 3s - loss: 5.3638e-05 - accuracy: 1.0000
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 3s - loss: 6.5989e-05 - accuracy: 1.0000
# Yielding: Chunk 6 (training)
# 6/8 [=====================>........] - ETA: 2s - loss: 8.0228e-05 - accuracy: 1.0000
# Yielding: Chunk 7 (training)
# 7/8 [=========================>....] - ETA: 1s - loss: 8.5098e-05 - accuracy: 1.0000
# Yielding: Chunk 8 (training)
# 8/8 [==============================] - ETA: 0s - loss: 9.2554e-05 - accuracy: 1.0000
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 21s 3s/step - loss: 9.2554e-05 - accuracy: 1.0000 - val_loss: 0.0603 - val_accuracy: 0.9816
# Epoch 37/50
# 1/8 [==>...........................] - ETA: 0s - loss: 5.9038e-05 - accuracy: 1.0000
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 4s - loss: 4.0209e-05 - accuracy: 1.0000
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 4s - loss: 4.9569e-05 - accuracy: 1.0000
# Yielding: Chunk 4 (training)
# 4/8 [==============>...............] - ETA: 4s - loss: 5.0791e-05 - accuracy: 1.0000
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 3s - loss: 6.2856e-05 - accuracy: 1.0000
# Yielding: Chunk 6 (training)
# 6/8 [=====================>........] - ETA: 2s - loss: 7.6761e-05 - accuracy: 1.0000
# Yielding: Chunk 7 (training)
# 7/8 [=========================>....] - ETA: 1s - loss: 8.1585e-05 - accuracy: 1.0000
# Yielding: Chunk 8 (training)
# 8/8 [==============================] - ETA: 0s - loss: 8.8832e-05 - accuracy: 1.0000
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 21s 3s/step - loss: 8.8832e-05 - accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 0.9807
# Epoch 38/50
# 1/8 [==>...........................] - ETA: 0s - loss: 5.8045e-05 - accuracy: 1.0000
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 4s - loss: 3.9367e-05 - accuracy: 1.0000
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 4s - loss: 4.8228e-05 - accuracy: 1.0000
# Yielding: Chunk 4 (training)
# 4/8 [==============>...............] - ETA: 3s - loss: 4.9358e-05 - accuracy: 1.0000
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 3s - loss: 6.0901e-05 - accuracy: 1.0000
# Yielding: Chunk 6 (training)
# 6/8 [=====================>........] - ETA: 2s - loss: 7.4323e-05 - accuracy: 1.0000
# Yielding: Chunk 7 (training)
# 7/8 [=========================>....] - ETA: 1s - loss: 7.8981e-05 - accuracy: 1.0000
# Yielding: Chunk 8 (training)
# 8/8 [==============================] - ETA: 0s - loss: 8.5937e-05 - accuracy: 1.0000
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 21s 3s/step - loss: 8.5937e-05 - accuracy: 1.0000 - val_loss: 0.0516 - val_accuracy: 0.9811
# Epoch 39/50
# 1/8 [==>...........................] - ETA: 0s - loss: 5.1276e-05 - accuracy: 1.0000
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 4s - loss: 3.5652e-05 - accuracy: 1.0000
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 4s - loss: 4.5010e-05 - accuracy: 1.0000
# Yielding: Chunk 4 (training)
# 4/8 [==============>...............] - ETA: 4s - loss: 4.6545e-05 - accuracy: 1.0000
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 3s - loss: 5.7891e-05 - accuracy: 1.0000
# Yielding: Chunk 6 (training)
# 6/8 [=====================>........] - ETA: 2s - loss: 7.1047e-05 - accuracy: 1.0000
# Yielding: Chunk 7 (training)
# 7/8 [=========================>....] - ETA: 1s - loss: 7.5685e-05 - accuracy: 1.0000
# Yielding: Chunk 8 (training)
# 8/8 [==============================] - ETA: 0s - loss: 8.2469e-05 - accuracy: 1.0000
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 21s 3s/step - loss: 8.2469e-05 - accuracy: 1.0000 - val_loss: 0.0494 - val_accuracy: 0.9816
# Epoch 40/50
# 1/8 [==>...........................] - ETA: 0s - loss: 5.9474e-05 - accuracy: 1.0000
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 4s - loss: 3.9445e-05 - accuracy: 1.0000
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 4s - loss: 4.6838e-05 - accuracy: 1.0000
# Yielding: Chunk 4 (training)
# 4/8 [==============>...............] - ETA: 4s - loss: 4.7535e-05 - accuracy: 1.0000
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 3s - loss: 5.7967e-05 - accuracy: 1.0000
# Yielding: Chunk 6 (training)
# 6/8 [=====================>........] - ETA: 2s - loss: 7.0386e-05 - accuracy: 1.0000
# Yielding: Chunk 7 (training)
# 7/8 [=========================>....] - ETA: 1s - loss: 7.4654e-05 - accuracy: 1.0000
# Yielding: Chunk 8 (training)
# 8/8 [==============================] - ETA: 0s - loss: 8.1017e-05 - accuracy: 1.0000
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 22s 3s/step - loss: 8.1017e-05 - accuracy: 1.0000 - val_loss: 0.0454 - val_accuracy: 0.9838
# Epoch 41/50
# 1/8 [==>...........................] - ETA: 0s - loss: 5.0627e-05 - accuracy: 1.0000
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 4s - loss: 3.4728e-05 - accuracy: 1.0000
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 4s - loss: 4.3029e-05 - accuracy: 1.0000
# Yielding: Chunk 4 (training)
# 4/8 [==============>...............] - ETA: 4s - loss: 4.4311e-05 - accuracy: 1.0000
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 3s - loss: 5.4716e-05 - accuracy: 1.0000
# Yielding: Chunk 6 (training)
# 6/8 [=====================>........] - ETA: 2s - loss: 6.6991e-05 - accuracy: 1.0000
# Yielding: Chunk 7 (training)
# 7/8 [=========================>....] - ETA: 1s - loss: 7.1295e-05 - accuracy: 1.0000
# Yielding: Chunk 8 (training)
# 8/8 [==============================] - ETA: 0s - loss: 7.7559e-05 - accuracy: 1.0000
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 21s 3s/step - loss: 7.7559e-05 - accuracy: 1.0000 - val_loss: 0.0475 - val_accuracy: 0.9852
# Epoch 42/50
# 1/8 [==>...........................] - ETA: 0s - loss: 5.0452e-05 - accuracy: 1.0000
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 4s - loss: 3.4368e-05 - accuracy: 1.0000
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 4s - loss: 4.2158e-05 - accuracy: 1.0000
# Yielding: Chunk 4 (training)
# 4/8 [==============>...............] - ETA: 4s - loss: 4.3311e-05 - accuracy: 1.0000
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 3s - loss: 5.3287e-05 - accuracy: 1.0000
# Yielding: Chunk 6 (training)
# 6/8 [=====================>........] - ETA: 2s - loss: 6.5150e-05 - accuracy: 1.0000
# Yielding: Chunk 7 (training)
# 7/8 [=========================>....] - ETA: 1s - loss: 6.9287e-05 - accuracy: 1.0000
# Yielding: Chunk 8 (training)
# 8/8 [==============================] - ETA: 0s - loss: 7.5308e-05 - accuracy: 1.0000
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 22s 3s/step - loss: 7.5308e-05 - accuracy: 1.0000 - val_loss: 0.0493 - val_accuracy: 0.9847
# Epoch 43/50
# 1/8 [==>...........................] - ETA: 0s - loss: 4.9613e-05 - accuracy: 1.0000
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 4s - loss: 3.3688e-05 - accuracy: 1.0000
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 4s - loss: 4.1109e-05 - accuracy: 1.0000
# Yielding: Chunk 4 (training)
# 4/8 [==============>...............] - ETA: 4s - loss: 4.2189e-05 - accuracy: 1.0000
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 3s - loss: 5.1787e-05 - accuracy: 1.0000
# Yielding: Chunk 6 (training)
# 6/8 [=====================>........] - ETA: 2s - loss: 6.3283e-05 - accuracy: 1.0000
# Yielding: Chunk 7 (training)
# 7/8 [=========================>....] - ETA: 1s - loss: 6.7286e-05 - accuracy: 1.0000
# Yielding: Chunk 8 (training)
# 8/8 [==============================] - ETA: 0s - loss: 7.3092e-05 - accuracy: 1.0000
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 21s 3s/step - loss: 7.3092e-05 - accuracy: 1.0000 - val_loss: 0.0488 - val_accuracy: 0.9856
# Epoch 44/50
# 1/8 [==>...........................] - ETA: 0s - loss: 5.0827e-05 - accuracy: 1.0000
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 3s - loss: 3.4038e-05 - accuracy: 1.0000
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 4s - loss: 4.0782e-05 - accuracy: 1.0000
# Yielding: Chunk 4 (training)
# 4/8 [==============>...............] - ETA: 4s - loss: 4.1618e-05 - accuracy: 1.0000
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 3s - loss: 5.0754e-05 - accuracy: 1.0000
# Yielding: Chunk 6 (training)
# 6/8 [=====================>........] - ETA: 2s - loss: 6.1835e-05 - accuracy: 1.0000
# Yielding: Chunk 7 (training)
# 7/8 [=========================>....] - ETA: 1s - loss: 6.5664e-05 - accuracy: 1.0000
# Yielding: Chunk 8 (training)
# 8/8 [==============================] - ETA: 0s - loss: 7.1226e-05 - accuracy: 1.0000
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 21s 3s/step - loss: 7.1226e-05 - accuracy: 1.0000 - val_loss: 0.0504 - val_accuracy: 0.9856
# Epoch 45/50
# 1/8 [==>...........................] - ETA: 0s - loss: 4.6714e-05 - accuracy: 1.0000
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 4s - loss: 3.1741e-05 - accuracy: 1.0000
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 4s - loss: 3.8714e-05 - accuracy: 1.0000
# Yielding: Chunk 4 (training)
# 4/8 [==============>...............] - ETA: 4s - loss: 3.9759e-05 - accuracy: 1.0000
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 3s - loss: 4.8726e-05 - accuracy: 1.0000
# Yielding: Chunk 6 (training)
# 6/8 [=====================>........] - ETA: 2s - loss: 5.9583e-05 - accuracy: 1.0000
# Yielding: Chunk 7 (training)
# 7/8 [=========================>....] - ETA: 1s - loss: 6.3371e-05 - accuracy: 1.0000
# Yielding: Chunk 8 (training)
# 8/8 [==============================] - ETA: 0s - loss: 6.8796e-05 - accuracy: 1.0000
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 22s 3s/step - loss: 6.8796e-05 - accuracy: 1.0000 - val_loss: 0.0529 - val_accuracy: 0.9865
# Epoch 46/50
# 1/8 [==>...........................] - ETA: 0s - loss: 4.5481e-05 - accuracy: 1.0000
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 4s - loss: 3.0896e-05 - accuracy: 1.0000
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 4s - loss: 3.7638e-05 - accuracy: 1.0000
# Yielding: Chunk 4 (training)
# 4/8 [==============>...............] - ETA: 4s - loss: 3.8658e-05 - accuracy: 1.0000
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 3s - loss: 4.7329e-05 - accuracy: 1.0000
# Yielding: Chunk 6 (training)
# 6/8 [=====================>........] - ETA: 2s - loss: 5.7884e-05 - accuracy: 1.0000
# Yielding: Chunk 7 (training)
# 7/8 [=========================>....] - ETA: 1s - loss: 6.1566e-05 - accuracy: 1.0000
# Yielding: Chunk 8 (training)
# 8/8 [==============================] - ETA: 0s - loss: 6.6814e-05 - accuracy: 1.0000
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 22s 3s/step - loss: 6.6814e-05 - accuracy: 1.0000 - val_loss: 0.0546 - val_accuracy: 0.9865
# Epoch 47/50
# 1/8 [==>...........................] - ETA: 0s - loss: 4.5783e-05 - accuracy: 1.0000
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 4s - loss: 3.0827e-05 - accuracy: 1.0000
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 4s - loss: 3.7096e-05 - accuracy: 1.0000
# Yielding: Chunk 4 (training)
# 4/8 [==============>...............] - ETA: 4s - loss: 3.7975e-05 - accuracy: 1.0000
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 3s - loss: 4.6293e-05 - accuracy: 1.0000
# Yielding: Chunk 6 (training)
# 6/8 [=====================>........] - ETA: 2s - loss: 5.6508e-05 - accuracy: 1.0000
# Yielding: Chunk 7 (training)
# 7/8 [=========================>....] - ETA: 1s - loss: 6.0054e-05 - accuracy: 1.0000
# Yielding: Chunk 8 (training)
# 8/8 [==============================] - ETA: 0s - loss: 6.5105e-05 - accuracy: 1.0000
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 21s 3s/step - loss: 6.5105e-05 - accuracy: 1.0000 - val_loss: 0.0583 - val_accuracy: 0.9870
# Epoch 48/50
# 1/8 [==>...........................] - ETA: 0s - loss: 4.7169e-05 - accuracy: 1.0000
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 4s - loss: 3.1310e-05 - accuracy: 1.0000
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 4s - loss: 3.6944e-05 - accuracy: 1.0000
# Yielding: Chunk 4 (training)
# 4/8 [==============>...............] - ETA: 4s - loss: 3.7593e-05 - accuracy: 1.0000
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 3s - loss: 4.5519e-05 - accuracy: 1.0000
# Yielding: Chunk 6 (training)
# 6/8 [=====================>........] - ETA: 2s - loss: 5.5375e-05 - accuracy: 1.0000
# Yielding: Chunk 7 (training)
# 7/8 [=========================>....] - ETA: 1s - loss: 5.8766e-05 - accuracy: 1.0000
# Yielding: Chunk 8 (training)
# 8/8 [==============================] - ETA: 0s - loss: 6.3605e-05 - accuracy: 1.0000
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 22s 3s/step - loss: 6.3605e-05 - accuracy: 1.0000 - val_loss: 0.0602 - val_accuracy: 0.9879
# Epoch 49/50
# 1/8 [==>...........................] - ETA: 0s - loss: 4.0594e-05 - accuracy: 1.0000
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 4s - loss: 2.7821e-05 - accuracy: 1.0000
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 4s - loss: 3.4164e-05 - accuracy: 1.0000
# Yielding: Chunk 4 (training)
# 4/8 [==============>...............] - ETA: 4s - loss: 3.5249e-05 - accuracy: 1.0000
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 3s - loss: 4.3198e-05 - accuracy: 1.0000
# Yielding: Chunk 6 (training)
# 6/8 [=====================>........] - ETA: 2s - loss: 5.2972e-05 - accuracy: 1.0000
# Yielding: Chunk 7 (training)
# 7/8 [=========================>....] - ETA: 1s - loss: 5.6404e-05 - accuracy: 1.0000
# Yielding: Chunk 8 (training)
# 8/8 [==============================] - ETA: 0s - loss: 6.1180e-05 - accuracy: 1.0000
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 22s 3s/step - loss: 6.1180e-05 - accuracy: 1.0000 - val_loss: 0.0600 - val_accuracy: 0.9883
# Epoch 50/50
# 1/8 [==>...........................] - ETA: 0s - loss: 4.1132e-05 - accuracy: 1.0000
# Yielding: Chunk 2 (training)
# 2/8 [======>.......................] - ETA: 4s - loss: 2.7900e-05 - accuracy: 1.0000
# Yielding: Chunk 3 (training)
# 3/8 [==========>...................] - ETA: 4s - loss: 3.3785e-05 - accuracy: 1.0000
# Yielding: Chunk 4 (training)
# 4/8 [==============>...............] - ETA: 4s - loss: 3.4716e-05 - accuracy: 1.0000
# Yielding: Chunk 5 (training)
# 5/8 [=================>............] - ETA: 3s - loss: 4.2350e-05 - accuracy: 1.0000
# Yielding: Chunk 6 (training)
# 6/8 [=====================>........] - ETA: 2s - loss: 5.1817e-05 - accuracy: 1.0000
# Yielding: Chunk 7 (training)
# 7/8 [=========================>....] - ETA: 1s - loss: 5.5126e-05 - accuracy: 1.0000
# Yielding: Chunk 8 (training)
# 8/8 [==============================] - ETA: 0s - loss: 5.9720e-05 - accuracy: 1.0000
# Yielding: Chunk 1 (training)
# 8/8 [==============================] - 22s 3s/step - loss: 5.9720e-05 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 0.9879

# %% [markdown]
# ## Experiment 4: Dropout regularization

# %%
# Sweep config
dropout_prob_list = [0.0, 0.1, 0.15, 0.2]

base_log_dir = "/content/drive/My Drive/DL-final_project/Results/Cross/Expt4-dropout/logs/"

# %%
for dropout_prob in dropout_prob_list:
   # Set up callback
  log_dir = base_log_dir +  "{}_dropout/".format(dropout_prob)
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir, histogram_freq=0, write_graph=True, write_images=False,
      update_freq='epoch', profile_batch=2, embeddings_freq=0,
      embeddings_metadata=None)

  # Initialize data generators
  train_generator = train_val_generator(train_data_dir, subject_id, 
                                                 'training', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                                 WINDOW_SIZE, WINDOW_SHIFT, 
                                                 maxs_array, mins_array)

  val_generator = train_val_generator(train_data_dir, subject_id, 
                                               'validation', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                               WINDOW_SIZE, WINDOW_SHIFT, 
                                               maxs_array, mins_array)

  # Initialize model
  model = CNN_model_cross(WINDOW_SIZE,
                    N_CONV_LAYERS, KERNELS, KERNEL_SIZES, 
                    hyper_params={'lr':0.001, 'batch_norm':False, 'dropout_prob':dropout_prob})
  
  # Start training
  print("EXPT CASE: Dropout-", dropout_prob)
  model.fit(train_generator,
              steps_per_epoch = 8,
              validation_data = val_generator,
              validation_steps = 8,
              epochs = EPOCHS,
              callbacks=[tensorboard_callback])

# %% [markdown]
# ## Experiment 5: Learning rate tuning

# %%
# Sweep config
learning_rate_list = [0.005, 0.007, 0.01, 0.03]

base_log_dir = "/content/drive/My Drive/DL-final_project/Results/Cross/Expt5-learningRate/logs/"

# %%
for i, learning_rate in enumerate(learning_rate_list):
  # Set up callback
  log_dir = base_log_dir +  "{}_learningRate/".format(learning_rate)
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir, histogram_freq=0, write_graph=True, write_images=False,
      update_freq='epoch', profile_batch=2, embeddings_freq=0,
      embeddings_metadata=None)

  # Initialize data generators
  train_generator = train_val_generator(train_data_dir, subject_id, 
                                                 'training', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                                 WINDOW_SIZE, WINDOW_SHIFT, 
                                                 maxs_array, mins_array)

  val_generator = train_val_generator(train_data_dir, subject_id, 
                                               'validation', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                               WINDOW_SIZE, WINDOW_SHIFT, 
                                               maxs_array, mins_array)

  # Initialize model
  model = CNN_model_cross(WINDOW_SIZE,
                    N_CONV_LAYERS, KERNELS, KERNEL_SIZES, 
                    hyper_params={'lr':learning_rate, 'batch_norm':False, 'dropout_prob':0.0})
  
  # Start training
  print("\nEXPT CASE: Learning rate-", learning_rate)
  model.fit(train_generator,
              steps_per_epoch = 8,
              validation_data = val_generator,
              validation_steps = 8,
              epochs = EPOCHS,
              callbacks=[tensorboard_callback])

# %% [markdown]
# ## Experiment 6: Weight initialization

# %%
# Sweep config

initializer_list = ['glorot_uniform'
                    'glorot_normal', 
                    'zeros', 
                    'random_normal',
                    'random_uniform']

base_log_dir = "/content/drive/My Drive/DL-final_project/Results/Cross/Expt6-weightInit/logs/"

# %%
for initializer in initializer_list:
     # Set up callback
  log_dir = base_log_dir +  "{}_weightInit/".format(initializer)
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir, histogram_freq=0, write_graph=True, write_images=False,
      update_freq='epoch', profile_batch=2, embeddings_freq=0,
      embeddings_metadata=None)

  # Initialize data generators
  train_generator = train_val_generator(train_data_dir, subject_id, 
                                                 'training', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                                 WINDOW_SIZE, WINDOW_SHIFT, 
                                                 maxs_array, mins_array)

  val_generator = train_val_generator(train_data_dir, subject_id, 
                                               'validation', DOWNSAMPLING_FACTOR, VAL_SPLIT, SHUFFLE, 
                                               WINDOW_SIZE, WINDOW_SHIFT, 
                                               maxs_array, mins_array)

  # Initialize model
  model = CNN_model_cross(WINDOW_SIZE,
                    N_CONV_LAYERS, KERNELS, KERNEL_SIZES, 
                    HYPER_PARAMS,
                    initializer)
  
  # Start training
  print("\nEXPT CASE: Initializer-", initializer)
  model.fit(train_generator,
              steps_per_epoch = 8,
              validation_data = val_generator,
              validation_steps = 8,
              epochs = EPOCHS,
              callbacks=[tensorboard_callback])
